# %% [markdown]
# # Tic-Tac-Toe
#
# A two-player Tic-Tac-Toe game for the command line.
#
# I made this one when I was bored in class one day and wanted to see if I could build a full working game on my own. Two players take turns choosing cells (a to i) on a 3x3 grid, and the program checks after every move whether someone has three in a row, column or diagonal.
#
# I know the win-checking is written out condition by condition rather than in a smart loop. I could shorten it today, but I decided to keep the code exactly as I originally wrote it, because that's how I thought about the problem at the time and it works.
#
# **Run:** open the notebook and run the cell, then follow the prompts.

# %%
#prog compl workkk:
p1=input("choose a username player one!")
p2=input("choose a username player two!")
print("welcome",p1,"and",p2,"!")
print("here's the name of each place on the table!")
def table2(x="  "):
  print(x+"+--+--+--+")
  print(x+"|"+"a "+"|"+"b "+"|"+"c "+"|")
  print(x+"+--+--+--+")
  print(x+"|"+"d "+"|"+"e "+"|"+"f "+"|")
  print(x+"+--+--+--+")
  print(x+"|"+"g "+"|"+"h "+"|"+"i "+"|")
  print(x+"+--+--+--+")
table2()
print("now let's start!")
vv="yes"
while vv=="yes":
  dic={"a":"  ","b":"  ","c":"  ",
        "d":"  ","e":"  ","f":"  ",
        "g":"  ","h":"  ","i":"  "}
  def newtable(x=dic):
    print(" "+"+--+--+--+")
    print(" "+"|"+x["a"]+"|"+x["b"]+"|"+x["c"]+"|")
    print(" "+"+--+--+--+")
    print(" "+"|"+x["d"]+"|"+x["e"]+"|"+x["f"]+"|")
    print(" "+"+--+--+--+")
    print(" "+"|"+x["g"]+"|"+x["h"]+"|"+x["i"]+"|")
    print(" "+"+--+--+--+")
  l=["a","b","c","d","e","f","g","h","i"]
  r=0
  while r<9:
    print("choose a case",p1,":")
    s=input("").lower()
    while s not in l:
      print("choose a correct case:",p1)
      s=input("").lower()
    else:
      while dic[s]!="  ":
        print("this case is taken,choose another one:",p1)
        s=input("").lower()
      else:
        dic[s]="X"+" "
        newtable()
        r+=1
        if dic["a"]=="X " and dic["b"]=="X " and dic["c"]=="X ":
          print(p1,"won!")
          vv=input("do you want to replay?")
          break
        elif dic["d"]=="X " and dic["e"]=="X " and dic["f"]=="X ":
          print(p1,"won!")
          vv=input("do you want to replay?")
          break
        elif dic["g"]=="X " and dic["h"]=="X " and dic["i"]=="X ":
          print(p1,"won!")
          vv=input("do you want to replay?")
          break
        elif dic["a"]=="X " and dic["d"]=="X " and dic["g"]=="X ":
          print(p1,"won!")
          vv=input("do you want to replay?")
          break
        elif dic["b"]=="X " and dic["e"]=="X " and dic["h"]=="X ":
          print(p1,"won!")
          vv=input("do you want to replay?")
          break
        elif dic["c"]=="X " and dic["f"]=="X " and dic["i"]=="X ":
          print(p1,"won!")
          vv=input("do you want to replay?")
          break
        elif dic["a"]=="X " and dic["e"]=="X " and dic["i"]=="X ":
          print(p1,"won!")
          vv=input("do you want to replay?")
          break
        elif dic["c"]=="X " and dic["e"]=="X " and dic["g"]=="X ":
          print(p1,"won!")
          vv=input("do you want to replay?")
          break
    if r<9:
      print("choose a case",p2,":")
      s1=input("").lower()
      while s1 not in l:
        print("choose a correct case:",p2)
        s1=input("").lower()
      else:
        while dic[s1]!="  ":
          print("this case is taken,choose another one:",p2)
          s1=input("").lower()
        else:
          dic[s1]="O"+" "
          newtable()
          r+=1
          if dic["a"]=="O " and dic["b"]=="O " and dic["c"]=="O ":
            print(p2,"won!")
            vv=input("do you want to replay?")
            break
          elif dic["d"]=="O " and dic["e"]=="O " and dic["f"]=="O ":
            print(p2,"won!")
            vv=input("do you want to replay?")
            break
          elif dic["g"]=="O " and dic["h"]=="O " and dic["i"]=="O ":
            print(p2,"won!")
            vv=input("do you want to replay?")
            break
          elif dic["a"]=="O " and dic["d"]=="O " and dic["g"]=="O ":
            print(p2,"won!")
            vv=input("do you want to replay?")
            break
          elif dic["b"]=="O " and dic["e"]=="O " and dic["h"]=="O ":
            print(p2,"won!")
            vv=input("do you want to replay?")
            break
          elif dic["c"]=="O " and dic["f"]=="O " and dic["i"]=="O ":
            print(p2,"won!")
            vv=input("do you want to replay?")
            break
          elif dic["a"]=="O " and dic["e"]=="O " and dic["i"]=="O ":
            print(p2,"won!")
            vv=input("do you want to replay?")
            break
          elif dic["c"]=="O " and dic["e"]=="O " and dic["g"]=="O ":
            print(p2,"won!")
            vv=input("do you want to replay?")
            break
  else:
    print("game over,no one won!")
    vv=input("do you want to replay?")
else:
  print("it's over!")
